# %% [markdown]
# <a href="https://colab.research.google.com/github/GerardMorenoC/programacio/blob/main/Sensor_de_llum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

import pandas as pd

df=pd.read_csv("llum 2.csv")

max=df.max()             #valor maxim de la taula de dades
min=df.min()             #valor minim de la taula de dades
mitjana= df.sum()/len(df) #mitjana de la taula de dades

print(max)
print(min)
print(mitjana)

df
# Out:
# ...
# sep=\t    time (font1)\t
# dtype: object
# sep=\t    0\t164
# dtype: object
#             sep=\t
# 0   time (font1)\t
# 1           0\t164
# 2       1.026\t149
# 3         2.048\t0
# 4        3.074\t71
# 5       4.096\t111
# 6        5.121\t96
# 7        6.144\t87
# 8         7.169\t0
# 9         8.192\t0
# 10        9.216\t0
# 11        10.24\t0
# 12       11.264\t0
# 13     12.288\t100
# 14     13.312\t124
# 15     14.336\t155
# 16      15.36\t132
# 17     16.384\t128
# 18      17.41\t125
# 19     18.432\t117
# 20     19.455\t242
# 21      20.48\t244
# 22     21.504\t230
# 23     22.528\t223
# 24     23.552\t187
# 25     24.576\t233
# 26     25.599\t248
# 27     26.624\t250
# 28      27.65\t250
# 29     28.671\t250
# 30     29.695\t250
# 31     30.719\t251
# 32     31.744\t251
# 33       32.769\t0
# 34     33.791\t154
# 35     34.815\t181
# 36     35.839\t179
# 37     36.864\t166
# 38     37.887\t147
# 39     38.912\t132
# 40     39.935\t172
# 41     40.961\t153
# ...

# %%
import pandas as pd

df=pd.read_csv("llum 2.csv")

max2=df.max()             #valor maxim de la taula de dades
min2=df.min()             #valor minim de la taula de dades
mitjana= df.sum()/len(df) #mitjana de la taula de dades

print(max2)
print(min2)
print(mitjana)

df
# Out:
# sep=\t    time (font1)\t
# dtype: object
# sep=\t    0\t65
# dtype: object
#             sep=\t
# 0   time (font1)\t
# 1            0\t65
# 2        1.024\t59
# 3        2.048\t88
# 4        3.072\t92
# 5        4.096\t82
# 6         5.12\t81
# 7       6.144\t102
# 8        7.17\t157
# 9        8.192\t92
# 10       9.216\t88
# 11       10.24\t94
# 12     11.265\t143
# 13     12.288\t156
# 14      13.312\t82
# 15      14.335\t80
# 16       15.36\t98
# 17     16.384\t149
# 18     17.408\t152
# 19      18.432\t81
# 20      19.456\t82
# 21      20.48\t115
# 22     21.504\t148
# 23     22.527\t147
# 24      23.552\t79
# 25      24.576\t92
# 26     25.599\t139
# 27     26.623\t151
# 28     27.648\t143
# 29      28.672\t83
# 30     29.696\t108
# 31      30.72\t146
# 32     31.743\t148
# 33     32.767\t137
# 34      33.791\t83
# 35     34.815\t125
# 36      35.84\t147
# 37     36.866\t148
# 38     37.887\t134
# 39      38.912\t88
# 40       39.936\t0
# 41      40.96\t136
# ...

# %%
import pandas as pd

df=pd.read_csv("llum 3.csv")

max3=df.max()             #valor maxim de la taula de dades
min3=df.min()             #valor minim de la taula de dades
mitjana= df.sum()/len(df) #mitjana de la taula de dades

print(max3)
print(min3)
print(mitjana)

df
# Out:
# sep=\t    time (font1)\t
# dtype: object
# sep=\t    0\t0
# dtype: object
#             sep=\t
# 0   time (font1)\t
# 1             0\t0
# 2         1.024\t0
# 3         2.048\t0
# 4         3.072\t0
# ..             ...
# 68     68.607\t254
# 69     69.631\t254
# 70     70.655\t245
# 71      71.68\t187
# 72       72.708\t0
#
# [73 rows x 1 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_15['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
# ...
