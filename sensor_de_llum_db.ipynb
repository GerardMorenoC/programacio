# %% [markdown]
# <a href="https://colab.research.google.com/github/GerardMorenoC/programacio/blob/main/sensor_de_llum_db.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

import pandas as pd

df=pd.read_csv("sensor db.csv")

df
# Out:
# ...
#             sep=\t
# 0   time (font1)\t
# 1            0\t56
# 2        2.769\t67
# 3         5.54\t63
# 4        8.312\t71
# 5       11.084\t63
# 6       13.853\t60
# 7       16.626\t71
# 8       19.395\t60
# 9       22.165\t60
# 10      24.936\t52
# 11      27.707\t48
# 12      30.483\t60
# 13      33.255\t52
# 14      34.038\t30
# 15       36.81\t60
# 16       39.58\t63
# 17       42.35\t63
# 18      45.123\t60
# 19      47.891\t60
# 20      50.664\t67
# 21      53.433\t60
# 22      56.204\t60
# 23       58.99\t60
# 24      61.746\t60
# 25      62.529\t52
# 26        65.3\t63
# 27      68.071\t67
# 28      70.842\t60
# 29      73.613\t56
# 30      76.384\t60
# 31      79.155\t56
# 32      81.927\t60
# 33      84.696\t56
# 34      87.471\t63
# 35      90.242\t63
# 36      93.011\t60
# 37      95.781\t60
# 38       98.55\t67
# 39     101.321\t60
# 40     104.092\t63
# 41     106.863\t60
# 42      106.886\t0
# 43     109.658\t67
# 44     112.427\t52
# 45       115.2\t60
# ...

# %%
import pandas as pd

df=pd.read_csv("sensor db 2.csv")

df
# Out:
#             sep=\t
# 0   time (font1)\t
# 1            0\t60
# 2        2.771\t63
# 3        5.553\t67
# 4        8.312\t56
# 5       11.085\t67
# 6       13.856\t75
# 7       16.626\t75
# 8       19.396\t67
# 9       20.184\t30
# 10      22.956\t71
# 11      25.726\t60
# 12      28.497\t67
# 13      31.268\t71
# 14      34.039\t63
# 15       36.81\t71
# 16      39.581\t75
# 17      42.351\t71
# 18      45.124\t71
# 19      47.893\t67
# 20      50.664\t48
# 21      53.436\t67
# 22      56.206\t63
# 23      58.977\t82
# 24      61.748\t60
# 25      64.519\t71
# 26       67.29\t97
# 27       70.06\t71
# 28      72.831\t63
# 29      75.603\t71
# 30      78.373\t75
# 31      81.146\t75
# 32      83.915\t67
# 33      86.685\t56
# 34      89.456\t71
# 35      92.227\t75
# 36      94.998\t67
# 37      97.769\t71
# 38     100.54\t101
# 39     103.311\t60
# 40     106.082\t71
# 41     108.853\t71
# 42      111.64\t71
# 43     114.394\t71
# 44     117.166\t67
# ...

# %%
import pandas as pd

df=pd.read_csv("sensor db 3.csv")

df
# Out:
#             sep=\t
# 0   time (font1)\t
# 1            0\t86
# 2       2.771\t105
# 3        5.541\t82
# 4       8.313\t108
# 5       11.996\t78
# 6       14.767\t82
# 7       17.537\t82
# 8       20.308\t78
# 9      23.083\t123
# 10      26.762\t86
# 11      29.533\t71
# 12     32.304\t120
# 13      35.077\t63
# 14      37.846\t86
# 15      40.617\t75
# 16      43.389\t78
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
# ...
